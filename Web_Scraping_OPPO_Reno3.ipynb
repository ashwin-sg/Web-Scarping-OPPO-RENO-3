# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwin-sg/Web-Scarping-OPPO-RENO-3/blob/master/Web_Scraping_OPPO_Reno3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup
import smtplib

# %%
url = 'https://www.amazon.in/dp/B07X9YNV5Y/ref=twister_B08FYDRSJF?_encoding=UTF8&psc=1'

# %%
headers = {'user-agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36'}

# %%
page=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
# title of the page
print(soup.title)
# Out:
# <title>OPPO Reno3 Pro (Auroral Blue, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers: Amazon.in: Electronics</title>

# %%
# get attributes
print(soup.title.name)

# get names
print(soup.title.string)

# begining navigation
print(soup.title.parent.name)

# getting specific values
print(soup.p)
# Out:
# title
# OPPO Reno3 Pro (Auroral Blue, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers: Amazon.in: Electronics
# link
# <p>Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.</p>

# %%
print(soup.find_all('p'))
# Out:
# [<p>Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.</p>, <p>No customer signatures are required at the time of delivery.</p>, <p>For Pay-on-Delivery orders, we recommend paying using Credit card/Debit card/Netbanking via the pay-link sent via SMS at the time of delivery. To pay by cash, place cash on top of the delivery box and step back.</p>, <p><a href="/b/ref=amb_link_1/257-3809760-9063547?ie=UTF8&amp;node=22159860031&amp;pf_rd_m=A1VBAL9TL5WCBF&amp;pf_rd_s=hero-quick-promo&amp;pf_rd_r=VB4BQHVP740VXGNSAWD0&amp;pf_rd_r=VB4BQHVP740VXGNSAWD0&amp;pf_rd_t=201&amp;pf_rd_p=9cd87845-e029-4b26-a03c-6a59ee60a85b&amp;pf_rd_p=9cd87845-e029-4b26-a03c-6a59ee60a85b&amp;pf_rd_i=B07X9YNV5Y" target="_blank"><b>Sign in/Create a free business account </b></a></p>, <p class="a-spacing-small a-size-small a-color-secondary" id="askDPSearchPromptLabel">
#         Find answers in product info, Q&amp;As, reviews
# ...

# %%
for para in soup.find_all('p'):
  print(para.string)
  print(str(para.text))
# Out:
# Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.
# Delivery Associate will place the order on your doorstep and step back to maintain a 2-meter distance.
# No customer signatures are required at the time of delivery.
# No customer signatures are required at the time of delivery.
# For Pay-on-Delivery orders, we recommend paying using Credit card/Debit card/Netbanking via the pay-link sent via SMS at the time of delivery. To pay by cash, place cash on top of the delivery box and step back.
# For Pay-on-Delivery orders, we recommend paying using Credit card/Debit card/Netbanking via the pay-link sent via SMS at the time of delivery. To pay by cash, place cash on top of the delivery box and step back.
# Sign in/Create a free business account
# Sign in/Create a free business account
#
#         Find answers in product info, Q&As, reviews
#
#
#         Find answers in product info, Q&As, reviews
#
#
# ...

# %%
a=soup.find(id='productTitle')
b=a.get_text()

# %%
print(b.strip())
# Out:
# OPPO Reno3 Pro (Auroral Blue, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers

# %%
price=soup.find(id='priceblock_ourprice')
price.get_text()
# Out:
# '₹\xa027,990.00'

# %%
cp=price.get_text()

# %%
s=cp[2:8]
s
# Out:
# '27,990'

# %%
c=27990.0

# %%
res= requests.get('https://www.flipkart.com/oppo-reno3-pro-auroral-blue-128-gb/p/itm05804cb14fc19')

# %%
soup=BeautifulSoup(res.text,'lxml')

# %%
name= soup.select('._3iZgFn')

# %%
price=soup.select('._1vC4OE._3qQ9m1')

# %%
price
# Out:
# [<div class="_1vC4OE _3qQ9m1">₹27,990</div>]

# %%
d=27990

# %%
c=29990

# %%
price=0
company=' '
if c<d:
  price=c
  company='Amazon'
else:
  price=d
  company='Flipkart'

# %%
print(price)
print(company)
# Out:
# 27990
# Flipkart

# %%
def send_mail():
  server=smtplib.SMTP('smtp.gmail.com', 588)
  server.ehlo()
  server.starttls()
  server.ehlo()
  server.login('machinelearningpositivedream@gmail.com','machinelearning1234')
subject='price fell down'
if company=='Flipkart':
  body='check the flipkart link: https://www.flipkart.com/oppo-reno3-pro-auroral-blue-128-gb/p/itm05804cb14fc19'
  msg=f'subject:{subject}\n\n{body}'
  server.sendmail(
      ashwyn.ghonmode@gmail.com
      ,msg
  )
  print('mail send')
  server.quit

else:
  body='check the amazon link: https://www.amazon.in/dp/B07X9YNV5Y/ref=twister_B08FYDRSJF?_encoding=UTF8&psc=1'
  msg=f'subject:{subject}\n\n{body}'
  server.sendmail(
      ashwyn.ghonmode@gmail.com
      ,msg
  )
  print('mail send')
  server.quit

# %%
send_mail()
